# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %%
# * Total Schools
# * Total Students
# * Total Budget
# * Average Math Score
# * Average Reading Score
# * % Passing Math (The percentage of students that passed math.)
# * % Passing Reading (The percentage of students that passed reading.)
# * % Overall Passing (The percentage of students that passed math **and** reading.)

    
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %%
total_schools = len(school_data_complete["school_name"].unique())
total_students = school_data_complete["student_name"].count()
total_budget = school_data_complete["budget"].sum()
avg_math_score = school_data_complete["math_score"].mean()
avg_reading_score = school_data_complete["reading_score"].mean()
# math passing calculation

math_pass_counts = len(school_data_complete[school_data_complete["math_score"] >= 70])
perc_math = (math_pass_counts * 100)/total_students

# Reading percentage calculation
read_pass_counts = len(school_data_complete[school_data_complete["reading_score"] >= 70])
perc_read = (read_pass_counts * 100)/total_students

# Overall passing counts & percentage


overall_counts = len(school_data_complete[(school_data_complete["reading_score"] >= 70) & (school_data_complete["math_score"] >= 70)])

perc_overall = (overall_counts * 100)/total_students


#Total Schools	Total Students	Total Budget	Average Math Score	Average Reading Score
#% Passing Math	% Passing Reading	% Overall Passing

dist_summary = {"Total Schools" : [total_schools],
                "Total Student" : [total_students],
                "Total Budget" : total_budget,
                "Average Math Score" : avg_math_score,
                "Average Reading Score" : avg_reading_score,
                "% Passing Math" : perc_math,
                "% Passing Reading" : perc_read,
                "% Overall Passing" : perc_overall
                }

pd.DataFrame(dist_summary)
# Out:
#    Total Schools  Total Student  Total Budget  Average Math Score  \
# 0             15          39170   82932329558           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %%
school_clean_df = school_data_complete.groupby(["school_name","type"]).mean()

rename_df = school_clean_df.rename(columns ={"type" : "Type", "reading_score" : "Average Reading Score","math_score":"Average Math Score","size":"Total Students","budget":"Total School Budget"})

rename_df["Per Student Budget"] = rename_df["Total School Budget"] / rename_df["Total Students"]

rename_df
# Out:
#                                 Student ID  Average Reading Score  \
# school_name           type
# Bailey High School    District     20358.5              81.033963
# Cabrera High School   Charter      16941.5              83.975780
# Figueroa High School  District      4391.0              81.158020
# Ford High School      District     36165.0              80.746258
# Griffin High School   Charter      12995.5              83.816757
# Hernandez High School District      9944.0              80.934412
# Holden High School    Charter      23060.0              83.814988
# Huang High School     District      1458.0              81.182722
# Johnson High School   District     32415.0              80.966394
# Pena High School      Charter      23754.5              84.044699
# Rodriguez High School District     28035.0              80.744686
# Shelton High School   Charter       6746.0              83.725724
# Thomas High School    Charter      38352.0              83.848930
# ...

# %%
# Per School math passing scores
Bailey_Math = len(school_data_complete[(school_data_complete.school_name == "Bailey High School") & (school_data_complete.math_score >= 70)])
Cabrera_Math = len(school_data_complete[(school_data_complete.school_name == "Cabrera High School") & (school_data_complete.math_score >= 70)])
Figueroa_Math = len(school_data_complete[(school_data_complete.school_name == "Figueroa High School") & (school_data_complete.math_score >= 70)])
Ford_Math = len(school_data_complete[(school_data_complete.school_name == "Ford High School") & (school_data_complete.math_score >= 70)])
Griffin_Math = len(school_data_complete[(school_data_complete.school_name == "Griffin High School") & (school_data_complete.math_score >= 70)])

Hernandez_Math = len(school_data_complete[(school_data_complete.school_name == "Hernandez High School") & (school_data_complete.math_score >= 70)])
Holden_Math = len(school_data_complete[(school_data_complete.school_name == "Holden High School") & (school_data_complete.math_score >= 70)])
Huang_Math = len(school_data_complete[(school_data_complete.school_name == "Huang High School") & (school_data_complete.math_score >= 70)])
Johnson_Math = len(school_data_complete[(school_data_complete.school_name == "Johnson High School") & (school_data_complete.math_score >= 70)])
Pena_Math = len(school_data_complete[(school_data_complete.school_name == "Pena High School") & (school_data_complete.math_score >= 70)])

Rodriguez_Math = len(school_data_complete[(school_data_complete.school_name == "Rodriguez High School") & (school_data_complete.math_score >= 70)])
Shelton_Math = len(school_data_complete[(school_data_complete.school_name == "Shelton High School") & (school_data_complete.math_score >= 70)])
Thomas_Math = len(school_data_complete[(school_data_complete.school_name == "Thomas High School") & (school_data_complete.math_score >= 70)])
Wilson_Math = len(school_data_complete[(school_data_complete.school_name == "Wilson High School") & (school_data_complete.math_score >= 70)])
Wright_Math = len(school_data_complete[(school_data_complete.school_name == "Wright High School") & (school_data_complete.math_score >= 70)])

# Per School Reading passing scores

Bailey_Read = len(school_data_complete[(school_data_complete.school_name == "Bailey High School") & (school_data_complete.reading_score >= 70)])
Cabrera_Read = len(school_data_complete[(school_data_complete.school_name == "Cabrera High School") & (school_data_complete.reading_score >= 70)])
Figueroa_Read = len(school_data_complete[(school_data_complete.school_name == "Figueroa High School") & (school_data_complete.reading_score >= 70)])
Ford_Read = len(school_data_complete[(school_data_complete.school_name == "Ford High School") & (school_data_complete.reading_score >= 70)])
Griffin_Read = len(school_data_complete[(school_data_complete.school_name == "Griffin High School") & (school_data_complete.reading_score >= 70)])

Hernandez_Read = len(school_data_complete[(school_data_complete.school_name == "Hernandez High School") & (school_data_complete.reading_score >= 70)])
Holden_Read = len(school_data_complete[(school_data_complete.school_name == "Holden High School") & (school_data_complete.reading_score >= 70)])
Huang_Read = len(school_data_complete[(school_data_complete.school_name == "Huang High School") & (school_data_complete.reading_score >= 70)])
Johnson_Read = len(school_data_complete[(school_data_complete.school_name == "Johnson High School") & (school_data_complete.reading_score >= 70)])
Pena_Read = len(school_data_complete[(school_data_complete.school_name == "Pena High School") & (school_data_complete.reading_score >= 70)])

Rodriguez_Read = len(school_data_complete[(school_data_complete.school_name == "Rodriguez High School") & (school_data_complete.reading_score >= 70)])
Shelton_Read = len(school_data_complete[(school_data_complete.school_name == "Shelton High School") & (school_data_complete.reading_score >= 70)])
Thomas_Read = len(school_data_complete[(school_data_complete.school_name == "Thomas High School") & (school_data_complete.reading_score >= 70)])
Wilson_Read = len(school_data_complete[(school_data_complete.school_name == "Wilson High School") & (school_data_complete.reading_score >= 70)])
Wright_Read = len(school_data_complete[(school_data_complete.school_name == "Wright High School") & (school_data_complete.reading_score >= 70)])

# Per School Math & Reading passing scores
Bailey_RM = len(school_data_complete[(school_data_complete.school_name == "Bailey High School") & (school_data_complete.reading_score >= 70) & (school_data_complete.math_score >= 70)])
Cabrera_RM = len(school_data_complete[(school_data_complete.school_name == "Cabrera High School") & (school_data_complete.reading_score >= 70) & (school_data_complete.math_score >= 70)])
Figueroa_RM = len(school_data_complete[(school_data_complete.school_name == "Figueroa High School") & (school_data_complete.reading_score >= 70) & (school_data_complete.math_score >= 70)]) 
Ford_RM = len(school_data_complete[(school_data_complete.school_name == "Ford High School") & (school_data_complete.reading_score >= 70) & (school_data_complete.math_score >= 70)])
Griffin_RM = len(school_data_complete[(school_data_complete.school_name == "Griffin High School") & (school_data_complete.reading_score >= 70) & (school_data_complete.math_score >= 70)]) 

Hernandez_RM = len(school_data_complete[(school_data_complete.school_name == "Hernandez High School") & (school_data_complete.reading_score >= 70) & (school_data_complete.math_score >= 70)])
Holden_RM = len(school_data_complete[(school_data_complete.school_name == "Holden High School") & (school_data_complete.reading_score >= 70) & (school_data_complete.math_score >= 70)])
Huang_RM = len(school_data_complete[(school_data_complete.school_name == "Huang High School") & (school_data_complete.reading_score >= 70) & (school_data_complete.math_score >= 70)]) 
Johnson_RM = len(school_data_complete[(school_data_complete.school_name == "Johnson High School") & (school_data_complete.reading_score >= 70) & (school_data_complete.math_score >= 70)])
Pena_RM = len(school_data_complete[(school_data_complete.school_name == "Pena High School") & (school_data_complete.reading_score >= 70) & (school_data_complete.math_score >= 70)])  

Rodriguez_RM = len(school_data_complete[(school_data_complete.school_name == "Rodriguez High School") & (school_data_complete.reading_score >= 70) & (school_data_complete.math_score >= 70)])
Shelton_RM = len(school_data_complete[(school_data_complete.school_name == "Shelton High School") & (school_data_complete.reading_score >= 70) & (school_data_complete.math_score >= 70)])
Thomas_RM = len(school_data_complete[(school_data_complete.school_name == "Thomas High School") & (school_data_complete.reading_score >= 70) & (school_data_complete.math_score >= 70)]) 
Wilson_RM = len(school_data_complete[(school_data_complete.school_name == "Wilson High School") & (school_data_complete.reading_score >= 70) & (school_data_complete.math_score >= 70)])
Wright_RM = len(school_data_complete[(school_data_complete.school_name == "Wright High School") & (school_data_complete.reading_score >= 70) & (school_data_complete.math_score >= 70)])

# %%
# Creating New DataFrame with 3 new columns 

pass_df = pd.DataFrame({
    "school_name": ["Bailey High School", "Cabrera High School", "Figueroa High School", "Ford High School", "Griffin High School","Hernandez High School","Holden High School","Huang High School","Johnson High School","Pena High School","Rodriguez High School","Shelton High School","Thomas High School","Wilson High School","Wright High School"],
    "type": ["District","Charter", "District", "District","Charter","District","Charter","District","District","Charter","District","Charter", "Charter","Charter","Charter"],
    "math_pass": [Bailey_Math, Cabrera_Math, Figueroa_Math, Ford_Math, Griffin_Math,Hernandez_Math,Holden_Math, Huang_Math, Johnson_Math, Pena_Math, Rodriguez_Math, Shelton_Math, Thomas_Math, Wilson_Math, Wright_Math ],
    "read_pass": [Bailey_Read, Cabrera_Read, Figueroa_Read, Ford_Read, Griffin_Read, Hernandez_Read, Holden_Read, Huang_Read, Johnson_Read, Pena_Read, Rodriguez_Read, Shelton_Read, Thomas_Read, Wilson_Read, Wright_Read ],
    "math_read_pass": [Bailey_RM, Cabrera_RM, Figueroa_RM, Ford_RM, Griffin_RM, Hernandez_RM, Holden_RM, Huang_RM, Johnson_RM, Pena_RM, Rodriguez_RM, Shelton_RM, Thomas_RM, Wilson_RM, Wright_RM]
})

pass_df
# Out:
#               school_name      type  math_pass  read_pass  math_read_pass
# 0      Bailey High School  District       3318       4077            2719
# 1     Cabrera High School   Charter       1749       1803            1697
# 2    Figueroa High School  District       1946       2381            1569
# 3        Ford High School  District       1871       2172            1487
# 4     Griffin High School   Charter       1371       1426            1330
# 5   Hernandez High School  District       3094       3748            2481
# 6      Holden High School   Charter        395        411             381
# 7       Huang High School  District       1916       2372            1561
# 8     Johnson High School  District       3145       3867            2549
# 9        Pena High School   Charter        910        923             871
# 10  Rodriguez High School  District       2654       3208            2119
# 11    Shelton High School   Charter       1653       1688            1583
# ...

# %%
school_summary = pd.merge(rename_df, pass_df, how="left", on=["school_name"])

school_summary
# Out:
#               school_name  Student ID  Average Reading Score  \
# 0      Bailey High School     20358.5              81.033963
# 1     Cabrera High School     16941.5              83.975780
# 2    Figueroa High School      4391.0              81.158020
# 3        Ford High School     36165.0              80.746258
# 4     Griffin High School     12995.5              83.816757
# 5   Hernandez High School      9944.0              80.934412
# 6      Holden High School     23060.0              83.814988
# 7       Huang High School      1458.0              81.182722
# 8     Johnson High School     32415.0              80.966394
# 9        Pena High School     23754.5              84.044699
# 10  Rodriguez High School     28035.0              80.744686
# 11    Shelton High School      6746.0              83.725724
# 12     Thomas High School     38352.0              83.848930
# 13     Wilson High School     14871.0              83.989488
# ...

# %%
school_summary.dtypes
# Out:
# school_name               object
# Student ID               float64
# Average Reading Score    float64
# Average Math Score       float64
# School ID                float64
# Total Students           float64
# Total School Budget      float64
# Per Student Budget       float64
# type                      object
# math_pass                  int64
# read_pass                  int64
# math_read_pass             int64
# dtype: object

# %%
school_summary["% Passing Math"] = (school_summary["math_pass"] * 100) / school_summary["Total Students"]
school_summary["% Passing Reading"] = (school_summary["read_pass"] * 100) / school_summary["Total Students"]
school_summary["% Overall Passing"] = (school_summary["math_read_pass"] * 100) / school_summary["Total Students"]

# %%
# Reorganizing columns as per the project requirements.
school_summary1 = school_summary[["school_name","type","Total Students","Total School Budget","Per Student Budget","Average Math Score","Average Reading Score","% Passing Math","% Passing Reading","% Overall Passing"]]

school_final_summary = school_summary1.rename(columns ={"school_name" : "School Name", "type" : "School Type"})

# Total School Summary Report 

school_final_summary
# Out:
#               School Name School Type  Total Students  Total School Budget  \
# 0      Bailey High School    District          4976.0            3124928.0
# 1     Cabrera High School     Charter          1858.0            1081356.0
# 2    Figueroa High School    District          2949.0            1884411.0
# 3        Ford High School    District          2739.0            1763916.0
# 4     Griffin High School     Charter          1468.0             917500.0
# 5   Hernandez High School    District          4635.0            3022020.0
# 6      Holden High School     Charter           427.0             248087.0
# 7       Huang High School    District          2917.0            1910635.0
# 8     Johnson High School    District          4761.0            3094650.0
# 9        Pena High School     Charter           962.0             585858.0
# 10  Rodriguez High School    District          3999.0            2547363.0
# ...

# %%
# Top Performing Schools (By % Overall Passing)

Top_sort_df = school_final_summary.sort_values(["% Overall Passing"], ascending = False)
Top_sort_df.head()
# Out:
#             School Name School Type  Total Students  Total School Budget  \
# 1   Cabrera High School     Charter          1858.0            1081356.0
# 12   Thomas High School     Charter          1635.0            1043130.0
# 4   Griffin High School     Charter          1468.0             917500.0
# 13   Wilson High School     Charter          2283.0            1319574.0
# 9      Pena High School     Charter           962.0             585858.0
#
#     Per Student Budget  Average Math Score  Average Reading Score  \
# 1                582.0           83.061895              83.975780
# 12               638.0           83.418349              83.848930
# 4                625.0           83.351499              83.816757
# 13               578.0           83.274201              83.989488
# 9                609.0           83.839917              84.044699
#
#     % Passing Math  % Passing Reading  % Overall Passing
# 1        94.133477          97.039828          91.334769
# ...

# %%
# Bottom Performing Schools (By % Overall Passing)

Top_sort_df = school_final_summary.sort_values(["% Overall Passing"], ascending = True)
Top_sort_df.head()
# Out:
#               School Name School Type  Total Students  Total School Budget  \
# 10  Rodriguez High School    District          3999.0            2547363.0
# 2    Figueroa High School    District          2949.0            1884411.0
# 7       Huang High School    District          2917.0            1910635.0
# 5   Hernandez High School    District          4635.0            3022020.0
# 8     Johnson High School    District          4761.0            3094650.0
#
#     Per Student Budget  Average Math Score  Average Reading Score  \
# 10               637.0           76.842711              80.744686
# 2                639.0           76.711767              81.158020
# 7                655.0           76.629414              81.182722
# 5                652.0           77.289752              80.934412
# 8                650.0           77.072464              80.966394
#
#     % Passing Math  % Passing Reading  % Overall Passing
# 10       66.366592          80.220055          52.988247
# ...

# %%
# Math Average Scores by Grades

#school_clean_df = school_data_complete.groupby(["school_name","type"]).mean()

school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %%
math_grade_df = school_final_summary

math_grade_df
# Out:
#               School Name School Type  Total Students  Total School Budget  \
# 0      Bailey High School    District          4976.0            3124928.0
# 1     Cabrera High School     Charter          1858.0            1081356.0
# 2    Figueroa High School    District          2949.0            1884411.0
# 3        Ford High School    District          2739.0            1763916.0
# 4     Griffin High School     Charter          1468.0             917500.0
# 5   Hernandez High School    District          4635.0            3022020.0
# 6      Holden High School     Charter           427.0             248087.0
# 7       Huang High School    District          2917.0            1910635.0
# 8     Johnson High School    District          4761.0            3094650.0
# 9        Pena High School     Charter           962.0             585858.0
# 10  Rodriguez High School    District          3999.0            2547363.0
# ...

# %%
# Math and Reading scores per grades

trial_df = school_data_complete.groupby(["school_name","grade"]).mean()
t_trial = trial_df[["math_score","reading_score"]]

t_trial
# Out:
#                              math_score  reading_score
# school_name           grade
# Bailey High School    10th    76.996772      80.907183
#                       11th    77.515588      80.945643
#                       12th    76.492218      80.912451
#                       9th     77.083676      81.303155
# Cabrera High School   10th    83.154506      84.253219
#                       11th    82.765560      83.788382
#                       12th    83.277487      84.287958
#                       9th     83.094697      83.676136
# Figueroa High School  10th    76.539974      81.408912
#                       11th    76.884344      80.640339
#                       12th    77.151369      81.384863
#                       9th     76.403037      81.198598
# Ford High School      10th    77.672316      81.262712
#                       11th    76.918058      80.403642
#                       12th    76.179963      80.662338
#                       9th     77.361345      80.632653
# ...

# %%
bin_df = math_grade_df[["Per Student Budget","Average Math Score","Average Reading Score","% Passing Math","% Passing Reading","% Overall Passing"]]

bin_df = bin_df.sort_values(["Per Student Budget"], ascending = True)

bin_df
# Out:
#     Per Student Budget  Average Math Score  Average Reading Score  \
# 13               578.0           83.274201              83.989488
# 6                581.0           83.803279              83.814988
# 1                582.0           83.061895              83.975780
# 14               583.0           83.682222              83.955000
# 11               600.0           83.359455              83.725724
# 9                609.0           83.839917              84.044699
# 4                625.0           83.351499              83.816757
# 0                628.0           77.048432              81.033963
# 10               637.0           76.842711              80.744686
# 12               638.0           83.418349              83.848930
# 2                639.0           76.711767              81.158020
# 3                644.0           77.102592              80.746258
# 8                650.0           77.072464              80.966394
# ...

# %%
bins = [0,584,629,644,675]

group_name = ["< $584","$585-629","$630-644","$645-675"]


bin_df["Spending Ranges (Per Student)"] = pd.cut(bin_df["Per Student Budget"],bins, labels = group_name )

#bin_df = pd.cut(bin_df["Per Student Budget"],bins, labels = group_name )

#bin_df.groupby["Spending Ranges (Per Student)"].mean()


#bin_df = bin_df.sort_values(["Spending Ranges (Per Student)"], ascending = True)

#bin_df = bin_df.set_index["Spending Ranges (Per Student)"]

bin_df
# Out:
#     Per Student Budget  Average Math Score  Average Reading Score  \
# 13               578.0           83.274201              83.989488
# 6                581.0           83.803279              83.814988
# 1                582.0           83.061895              83.975780
# 14               583.0           83.682222              83.955000
# 11               600.0           83.359455              83.725724
# 9                609.0           83.839917              84.044699
# 4                625.0           83.351499              83.816757
# 0                628.0           77.048432              81.033963
# 10               637.0           76.842711              80.744686
# 12               638.0           83.418349              83.848930
# 2                639.0           76.711767              81.158020
# 3                644.0           77.102592              80.746258
# 8                650.0           77.072464              80.966394
# ...

# %%
# Score by School Size
school_bin_df = math_grade_df[["Total Students","Average Math Score","Average Reading Score","% Passing Math","% Passing Reading","% Overall Passing"]]

#bin_df = bin_df.sort_values(["Spending Ranges (Per Student)"], ascending = True)

school_bin_df.reset_index()
school_bin_df.sort_values(by=["Total Students"],ascending = True)

school_bins = [0,1000,2000,5000]

size_group = ["Small(<1000)","Medium(1000-2000)","Large(2000-5000)"]

school_bin_df["School Size"] = pd.cut(school_bin_df["Total Students"],school_bins, labels = size_group )

#school_bin_df[["School_size","Average Math Score","Average Reading Score","% Passing Math","% Passing Reading","% Overall Passing"]]

#school_bin_rev_df = school_bin_df.groupby(["School Size"])


#school_bin_rev_df

school_bin_df
# Out:
# /Users/prashantkapadia/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
#     Total Students  Average Math Score  Average Reading Score  % Passing Math  \
# 0           4976.0           77.048432              81.033963       66.680064
# 1           1858.0           83.061895              83.975780       94.133477
# 2           2949.0           76.711767              81.158020       65.988471
# 3           2739.0           77.102592              80.746258       68.309602
# 4           1468.0           83.351499              83.816757       93.392371
# 5           4635.0           77.289752              80.934412       66.752967
# ...

# %%
#Scores by school Type


school_type_df = math_grade_df.copy()

school_type_df = school_type_df[["School Type","Average Math Score","Average Reading Score","% Passing Math","% Passing Reading","% Overall Passing"]]

school_type_df.reset_index()

#school_type_df["School Type"] = school_type_df["School Type"].astype(str)

school_type_df.set_index('School Type')
school_type_df.groupby(["School Type"])


school_type_df
#school_type_df
# Out:
#    School Type  Average Math Score  Average Reading Score  % Passing Math  \
# 0     District           77.048432              81.033963       66.680064
# 1      Charter           83.061895              83.975780       94.133477
# 2     District           76.711767              81.158020       65.988471
# 3     District           77.102592              80.746258       68.309602
# 4      Charter           83.351499              83.816757       93.392371
# 5     District           77.289752              80.934412       66.752967
# 6      Charter           83.803279              83.814988       92.505855
# 7     District           76.629414              81.182722       65.683922
# 8     District           77.072464              80.966394       66.057551
# 9      Charter           83.839917              84.044699       94.594595
# 10    District           76.842711              80.744686       66.366592
# 11     Charter           83.359455              83.725724       93.867121
# ...

# %%
school_type_df.dtypes
# Out:
# School Type               object
# Average Math Score       float64
# Average Reading Score    float64
# % Passing Math           float64
# % Passing Reading        float64
# % Overall Passing        float64
# dtype: object
